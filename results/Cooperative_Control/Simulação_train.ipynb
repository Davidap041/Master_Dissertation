# %% [markdown]
# # Controle e Modelagem para o sistema de agrupamento de automatos

# %% [markdown]
# ## Modelagem em rede de petri para caso de sistema e ultrapassagem de dois agentes
# ### Pista
# ![image-4.png](attachment:image-4.png)
# ### Rede de Petri da Pista
# ![image-6.png](attachment:image-6.png)
# ### Conjunto de Cores
# ![image-5.png](attachment:image-5.png)
#
# ### Rede de Petri do controle de ultrapassagem
# #### Controle de ultrapasagem por X1
# ![image.png](attachment:image.png)
#
# ### Controle de recepção por X2
# ![image-2.png](attachment:image-2.png)
#
# ### casos análogos para as outras linhas
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Modelagem em rede de petri para o caso de 3 agentes
# ## Pista
# ![image.png](attachment:image.png)
# ### Rede de Petri da Pista
# ![image-2.png](attachment:image-2.png)
#
# ### Conjunto de Cores
# ![image-3.png](attachment:image-3.png)
